# %%
import time
print('자는 중...')
time.sleep(10)
print('다 잤음..')
# Out:
# 자는 중...
# 다 잤음..

# %%
# %%html
# <font color='red'>안녕? HTML이야</font>
# Out:
# <font color='red'>안녕? HTML이야</font>

# %%
# %%html
# <marquee style='width: 30%; color: blue;'><b>파이팅</b></marquee>
# Out:
# <marquee style='width: 30%; color:blue;'><b>파이팅</b></marquee>

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
y = 200 + np.random.randn(100)

# %%
x = [x for x in range(len(y))]

# %%
plt.plot(x, y, '-')
plt.title('Filled Example')
plt.fill_between(x,y, 195, where=(y>195), facecolor='r', alpha=0.6)
plt.show()
